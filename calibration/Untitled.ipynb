# %%
import os

# Получаем список всех файлов в текущей директории
files = os.listdir()

# Проходим по каждому файлу
count = 0
for file in files:
    # Проверяем, что файл имеет расширение .txt
    if file.endswith('.txt'):
        try:
            count += 1
            # Открываем файл и читаем первую строку
            with open(file, 'r', encoding='utf-8') as f:
                first_line = f.readline().strip()
                print(f"{first_line}")
        except Exception as e:
            print(f"Ошибка при чтении файла {file}: {e}")
count
# Out:
# Банк России с апреля повышает коэффициенты по операциям с участием центрального контрагента
# Ориентировочный срок повышения нормативов обязательных резервов перенесен на 1 марта
# Банк России изменил параметры предоставления средств на аукционах репо на срок 1 месяц
# Банк России изменяет сроки публикации первой оценки платежного баланса
# Банк России уточняет порядок формирования обязательных резервов по рублевым счетам типа «И»
# Банк России принял решение сохранить ключевую ставку на уровне 21,00% годовых
# Банк России переходит к проведению недельных аукционов репо
# С 1 апреля возобновляется ограничение ПСК по потребительским кредитам и займам
# Банк России принял решение сохранить ключевую ставку на уровне 21,00% годовых
# Банк России снижает макропруденциальные надбавки по кредитным картам в льготном периоде
# Банк России модифицирует подходы к оценке риска по ссудам МСП
# Банк России увеличивает лимит по механизму поддержки кредитования МСП
# Банк России систематизирует подходы к формированию официальных курсов иностранных валют
# Банк России отменяет ограничение ПСК по потребительским кредитам (займам) с 1 января по 31 марта 2025 года
# Антикризисные меры для профессиональных участников рынка ценных бумаг, управляющих компаний, негосударственных пенсионных фондов и инфраструктурных организаций финансового рынка (в части раскрытия информации) в 2025 году
# Банк России принял решение сохранить ключевую ставку на уровне 21,00% годовых
# Банк России принял ряд решений по банковскому регулированию
# Банк России продлевает послабления для страхового рынка, срок действия которых истекает 31 декабря 2024 года
# Банк России принял ряд решений по макропруденциальным требованиям в отношении необеспеченных потребительских кредитов
# Банк России возобновляет проведение аукционов репо на срок 1 месяц
# Банк России отменяет ограничение ПСК по кредитным картам с 1 января по 31 марта 2025 года
# Банк России предоставил кредитным организациям возможность увеличить лимиты безотзывных кредитных линий
# Банк России принял решение снизить ключевую ставку на 100 б.п., до 20,00% годовых
# Банк России принял ряд решений по банковскому регулированию
# Банк России уточнил подходы к формированию обеспечения по своим операциям
# Банк России принял решение повысить ключевую ставку на 200 б.п., до 21,00% годовых
# Банк России расширяет стимулирующее регулирование для проектов технологического суверенитета и структурной адаптации
# Банк России отменяет ограничение ПСК по ипотеке до 31 марта 2025 года
# Банк России изменил параметры валютных свопов
# Банк России принял решение повысить ключевую ставку на 100 б.п., до 19,00% годовых
# Банк России установил более строгие ограничения на кредитование заемщиков с высокой долговой нагрузкой, а также повысил макропруденциальные надбавки по нецелевым потребительским кредитам с залогом транспортного средства
# Банк России установил национальную антициклическую надбавку к нормативам достаточности капитала на уровне 0,25 процента от взвешенных по риску активов
# Банк России принял решение повысить ключевую ставку на 200 б.п., до 18,00% годовых
# Опубликована новая редакция Условий проведения операций по предоставлению и погашению кредитов Банка России
# Банк России приостанавливает публикацию статистики внебиржевого валютного рынка
# Банк России изменил параметры валютных свопов
# Банк России повышает макропруденциальные надбавки по необеспеченным потребительским кредитам
# С 1 июля прекращается действие моратория на применение ограничения ПСК по потребительским кредитам и отдельным видам займов
# Банк России временно отменяет утренние торги на Мосбирже
# Банк России приостанавливает торги гонконгским долларом и изменяет время начала торговой сессии на Мосбирже
# Банк России принял решение сохранить ключевую ставку на уровне 16,00% годовых
# Банк России создает Службу финансового мониторинга и валютного контроля
# Банк России установил более строгие ограничения на кредитование заемщиков с высокой долговой нагрузкой
# Банк России повышает макропруденциальные требования по необеспеченным потребительским кредитам и устанавливает требования по автокредитам
# Механизм поддержки кредитования субъектов МСП дополнен кредитами под залог ОФЗ
# Банк России принял решение сохранить ключевую ставку на уровне 16,00% годовых
# Банк России повышает с июня нормативы обязательных резервов
# Банк России установил дифференцированные нормативы обязательных резервов по видам иностранных валют
# Банк России внес изменения в Условия проведения операций по предоставлению и погашению кредитов
# Банк России запускает инструмент «валютный своп» по предоставлению юаней
# 50
